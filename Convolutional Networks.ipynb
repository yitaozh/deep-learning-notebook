# %% [markdown]
# # 1. TensorFlow Convolution Layer

# %% [markdown]
# TensorFlow provides the **tf.nn.conv2d()** and **tf.nn.bias_add()** functions to create your own convolutional layers.

# %%
import tensorflow as tf

# Output depth
k_output = 64

# Image Properties
image_width = 10
image_height = 10
color_channels = 3

# Convolution filter
filter_size_width = 5
filter_size_height = 5

# Input/Image
input = tf.placeholder(
    tf.float32,
    shape=[None, image_height, image_width, color_channels])

# Weight and bias
weight = tf.Variable(tf.truncated_normal(
    [filter_size_height, filter_size_width, color_channels, k_output]))
bias = tf.Variable(tf.zeros(k_output))

# Apply Convolution
conv_layer = tf.nn.conv2d(input, weight, strides=[1, 2, 2, 1], padding='SAME')
# Add bias
conv_layer = tf.nn.bias_add(conv_layer, bias)
# Apply activation function
conv_layer = tf.nn.relu(conv_layer)

# %% [markdown]
# TensorFlow provides the **tf.nn.max_pool()** function to apply max pooling to your convolutional layers.

# %%
# Apply Max Pooling
conv_layer = tf.nn.max_pool(
    conv_layer,
    ksize=[1, 2, 2, 1],
    strides=[1, 2, 2, 1],
    padding='SAME')

# %% [markdown]
# The **tf.nn.max_pool()** function performs max pooling with the ksize parameter as the size of the filter and the strides parameter as the length of the stride. 2x2 filters with a stride of 2x2 are common in practice.
#
# The ksize and strides parameters are structured as 4-element lists, with each element corresponding to a dimension of the input tensor ([batch, height, width, channels]). For both ksize and strides, the batch and channel dimensions are typically set to 1.

# %% [markdown]
# # 2. Convolutional Network in TensorFlow

# %% [markdown]
# ## Dataset

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets(".", one_hot=True, reshape=False)

import tensorflow as tf

# Parameters
learning_rate = 0.00001
epochs = 10
batch_size = 128

# Number of samples to calculate validation and accuracy
# Decrease this if you're running out of memory to calculate accuracy
test_valid_size = 256

# Network Parameters
n_classes = 10  # MNIST total classes (0-9 digits)
dropout = 0.75  # Dropout, probability to keep units
# Out:
# Extracting .\train-images-idx3-ubyte.gz
# Extracting .\train-labels-idx1-ubyte.gz
# Extracting .\t10k-images-idx3-ubyte.gz
# Extracting .\t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Weights and Biases

# %%
# Store layers weight & bias
weights = {
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    'out': tf.Variable(tf.random_normal([1024, n_classes]))}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))}

# %% [markdown]
# ## Convolutions

# %%
def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

# %% [markdown]
# ## Max Pooling

# %%
def maxpool2d(x, k=2):
    return tf.nn.max_pool(
        x,
        ksize=[1, k, k, 1],
        strides=[1, k, k, 1],
        padding='SAME')

# %% [markdown]
# ## Model

# %%
def conv_net(x, weights, biases, dropout):
    # Layer 1 - 28*28*1 to 14*14*32
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2)

    # Layer 2 - 14*14*32 to 7*7*64
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer - 7*7*64 to 1024
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output Layer - class prediction - 1024 to 10
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %% [markdown]
# ## Session

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, 28, 28, 1])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# Model
logits = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(\
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf. global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    for epoch in range(epochs):
        for batch in range(mnist.train.num_examples//batch_size):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: dropout})

            # Calculate batch loss and accuracy
            loss = sess.run(cost, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: 1.})
            valid_acc = sess.run(accuracy, feed_dict={
                x: mnist.validation.images[:test_valid_size],
                y: mnist.validation.labels[:test_valid_size],
                keep_prob: 1.})

            print('Epoch {:>2}, Batch {:>3} -'
                  'Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                epoch + 1,
                batch + 1,
                loss,
                valid_acc))

    # Calculate Test Accuracy
    test_acc = sess.run(accuracy, feed_dict={
        x: mnist.test.images[:test_valid_size],
        y: mnist.test.labels[:test_valid_size],
        keep_prob: 1.})
    print('Testing Accuracy: {}'.format(test_acc))
# Out:
# Epoch  1, Batch   1 -Loss: 58850.1797 Validation Accuracy: 0.093750
# Epoch  1, Batch   2 -Loss: 49100.5078 Validation Accuracy: 0.097656
# Epoch  1, Batch   3 -Loss: 37811.1797 Validation Accuracy: 0.128906
# Epoch  1, Batch   4 -Loss: 35359.1914 Validation Accuracy: 0.136719
# Epoch  1, Batch   5 -Loss: 33781.9961 Validation Accuracy: 0.160156
# Epoch  1, Batch   6 -Loss: 27484.6250 Validation Accuracy: 0.164062
# Epoch  1, Batch   7 -Loss: 20647.8789 Validation Accuracy: 0.175781
# Epoch  1, Batch   8 -Loss: 23996.7695 Validation Accuracy: 0.187500
# Epoch  1, Batch   9 -Loss: 23008.8809 Validation Accuracy: 0.199219
# Epoch  1, Batch  10 -Loss: 19049.0078 Validation Accuracy: 0.210938
# Epoch  1, Batch  11 -Loss: 18789.4570 Validation Accuracy: 0.234375
# Epoch  1, Batch  12 -Loss: 18923.9258 Validation Accuracy: 0.226562
# Epoch  1, Batch 393 -Loss:   952.7727 Validation Accuracy: 0.691406
# Epoch  1, Batch 394 -Loss:  1274.6565 Validation Accuracy: 0.695312
# Epoch  1, Batch 395 -Loss:  1805.4636 Validation Accuracy: 0.699219
# Epoch  1, Batch 396 -Loss:  1567.5737 Validation Accuracy: 0.707031
# Epoch  1, Batch 397 -Loss:  1152.2133 Validation Accuracy: 0.691406
# Epoch  1, Batch 398 -Loss:  1534.4639 Validation Accuracy: 0.703125
# Epoch  1, Batch 399 -Loss:  1334.7788 Validation Accuracy: 0.707031
# Epoch  1, Batch 400 -Loss:  1770.0857 Validation Accuracy: 0.714844
# Epoch  1, Batch 401 -Loss:  1187.1715 Validation Accuracy: 0.703125
# Epoch  1, Batch 402 -Loss:   953.2036 Validation Accuracy: 0.703125
# Epoch  1, Batch 403 -Loss:  1609.0005 Validation Accuracy: 0.699219
# Epoch  1, Batch 404 -Loss:  1537.7236 Validation Accuracy: 0.699219
# Epoch  1, Batch 405 -Loss:  1163.0928 Validation Accuracy: 0.699219
# Epoch  1, Batch 406 -Loss:   877.2021 Validation Accuracy: 0.695312
# Epoch  1, Batch 407 -Loss:  1436.0295 Validation Accuracy: 0.695312
# Epoch  1, Batch 408 -Loss:  1218.5681 Validation Accuracy: 0.699219
# Epoch  1, Batch 409 -Loss:  2014.0385 Validation Accuracy: 0.703125
# Epoch  1, Batch 410 -Loss:  1338.3169 Validation Accuracy: 0.703125
# Epoch  1, Batch 411 -Loss:  1344.6877 Validation Accuracy: 0.699219
# Epoch  1, Batch 412 -Loss:  2250.1567 Validation Accuracy: 0.699219
# Epoch  1, Batch 413 -Loss:   809.3699 Validation Accuracy: 0.710938
# Epoch  1, Batch 414 -Loss:  1200.5647 Validation Accuracy: 0.710938
# Epoch  1, Batch 415 -Loss:  1226.2456 Validation Accuracy: 0.699219
# Epoch  1, Batch 416 -Loss:   617.4601 Validation Accuracy: 0.703125
# Epoch  1, Batch 417 -Loss:   886.0483 Validation Accuracy: 0.707031
# Epoch  1, Batch 418 -Loss:  1450.2040 Validation Accuracy: 0.710938
# Epoch  1, Batch 419 -Loss:   504.4227 Validation Accuracy: 0.707031
# Epoch  1, Batch 420 -Loss:   689.5610 Validation Accuracy: 0.707031
# Epoch  1, Batch 421 -Loss:   974.1860 Validation Accuracy: 0.707031
# Epoch  1, Batch 422 -Loss:   639.0576 Validation Accuracy: 0.699219
# Epoch  1, Batch 423 -Loss:   545.2861 Validation Accuracy: 0.703125
# Epoch  1, Batch 424 -Loss:   835.5946 Validation Accuracy: 0.707031
# Epoch  1, Batch 425 -Loss:  2007.1653 Validation Accuracy: 0.699219
# Epoch  1, Batch 426 -Loss:  1552.6237 Validation Accuracy: 0.699219
# Epoch  1, Batch 427 -Loss:   521.8063 Validation Accuracy: 0.699219
# Epoch  1, Batch 428 -Loss:  1352.3323 Validation Accuracy: 0.699219
# Epoch  1, Batch 429 -Loss:   993.8185 Validation Accuracy: 0.695312
# Epoch  2, Batch   1 -Loss:  1446.9514 Validation Accuracy: 0.687500
# Epoch  2, Batch   2 -Loss:  1774.0920 Validation Accuracy: 0.699219
# Epoch  2, Batch   3 -Loss:  1665.9413 Validation Accuracy: 0.699219
# Epoch  2, Batch   4 -Loss:  1601.3604 Validation Accuracy: 0.699219
# Epoch  2, Batch   5 -Loss:  1337.8538 Validation Accuracy: 0.699219
# Epoch  2, Batch   6 -Loss:  1550.4954 Validation Accuracy: 0.699219
# Epoch  2, Batch   7 -Loss:  1336.8181 Validation Accuracy: 0.703125
# Epoch  2, Batch   8 -Loss:  1351.8914 Validation Accuracy: 0.695312
# Epoch  2, Batch   9 -Loss:  1655.0161 Validation Accuracy: 0.699219
# Epoch  2, Batch  10 -Loss:  1281.1602 Validation Accuracy: 0.699219
# Epoch  2, Batch  11 -Loss:  1136.5896 Validation Accuracy: 0.699219
# Epoch  2, Batch  12 -Loss:  1559.9686 Validation Accuracy: 0.703125
# Epoch  2, Batch  13 -Loss:  1639.9722 Validation Accuracy: 0.699219
# Epoch  2, Batch  14 -Loss:  1570.8905 Validation Accuracy: 0.699219
# Epoch  2, Batch  15 -Loss:  1381.4606 Validation Accuracy: 0.699219
# Epoch  2, Batch  16 -Loss:  1319.9642 Validation Accuracy: 0.707031
# Epoch  2, Batch  17 -Loss:  1338.2394 Validation Accuracy: 0.703125
# Epoch  2, Batch  18 -Loss:  1807.8191 Validation Accuracy: 0.703125
# Epoch  2, Batch  19 -Loss:  1491.5289 Validation Accuracy: 0.710938
# Epoch  2, Batch  20 -Loss:  1807.8862 Validation Accuracy: 0.703125
# Epoch  2, Batch  21 -Loss:  1332.3818 Validation Accuracy: 0.707031
# Epoch  2, Batch  22 -Loss:   846.8816 Validation Accuracy: 0.703125
# Epoch  2, Batch  23 -Loss:  1398.4097 Validation Accuracy: 0.707031
# Epoch  2, Batch  24 -Loss:  1812.7673 Validation Accuracy: 0.710938
# Epoch  2, Batch  25 -Loss:  1068.3264 Validation Accuracy: 0.710938
# Epoch  2, Batch  26 -Loss:  1044.2410 Validation Accuracy: 0.703125
# Epoch  2, Batch  27 -Loss:  1532.1495 Validation Accuracy: 0.703125
# Epoch  2, Batch  28 -Loss:  1066.2635 Validation Accuracy: 0.699219
# Epoch  2, Batch  29 -Loss:  1529.5051 Validation Accuracy: 0.714844
# Epoch  2, Batch  30 -Loss:  1344.8391 Validation Accuracy: 0.707031
# Epoch  2, Batch  31 -Loss:  1352.7551 Validation Accuracy: 0.707031
# Epoch  2, Batch  32 -Loss:  1192.5790 Validation Accuracy: 0.707031
# Epoch  2, Batch  33 -Loss:  1559.5308 Validation Accuracy: 0.710938
# Epoch  2, Batch  34 -Loss:  1365.4285 Validation Accuracy: 0.710938
# Epoch  2, Batch  35 -Loss:  1224.9885 Validation Accuracy: 0.710938
# Epoch  2, Batch  36 -Loss:   966.7394 Validation Accuracy: 0.707031
# Epoch  2, Batch  37 -Loss:  1063.6047 Validation Accuracy: 0.710938
# Epoch  2, Batch  38 -Loss:  1108.2772 Validation Accuracy: 0.710938
# Epoch  2, Batch  39 -Loss:  1381.2488 Validation Accuracy: 0.710938
# Epoch  2, Batch  40 -Loss:  1233.7961 Validation Accuracy: 0.707031
# Epoch  2, Batch  41 -Loss:  1516.8776 Validation Accuracy: 0.710938
# Epoch  2, Batch  42 -Loss:  1680.7917 Validation Accuracy: 0.707031
# Epoch  2, Batch  43 -Loss:   926.8538 Validation Accuracy: 0.710938
# Epoch  2, Batch  44 -Loss:  1152.7511 Validation Accuracy: 0.714844
# Epoch  2, Batch  45 -Loss:  1351.8020 Validation Accuracy: 0.718750
# Epoch  2, Batch  46 -Loss:   938.5895 Validation Accuracy: 0.714844
# Epoch  2, Batch  47 -Loss:  1094.0599 Validation Accuracy: 0.718750
# Epoch  2, Batch  48 -Loss:  1123.2386 Validation Accuracy: 0.710938
# Epoch  2, Batch  49 -Loss:   879.3033 Validation Accuracy: 0.707031
# Epoch  2, Batch  50 -Loss:  1309.7129 Validation Accuracy: 0.707031
# Epoch  2, Batch  51 -Loss:   842.2402 Validation Accuracy: 0.710938
# Epoch  2, Batch  52 -Loss:  1032.2563 Validation Accuracy: 0.714844
# Epoch  2, Batch  53 -Loss:  1088.1947 Validation Accuracy: 0.714844
# Epoch  2, Batch  54 -Loss:  1689.4646 Validation Accuracy: 0.710938
# Epoch  2, Batch  55 -Loss:  1149.0920 Validation Accuracy: 0.714844
# Epoch  2, Batch  56 -Loss:   903.5297 Validation Accuracy: 0.722656
# Epoch  2, Batch  57 -Loss:  1155.4895 Validation Accuracy: 0.714844
# Epoch  2, Batch  58 -Loss:  1404.6293 Validation Accuracy: 0.718750
# Epoch  2, Batch  59 -Loss:  1426.1309 Validation Accuracy: 0.714844
# Epoch  2, Batch  60 -Loss:   997.4836 Validation Accuracy: 0.718750
# Epoch  2, Batch  61 -Loss:  1970.1216 Validation Accuracy: 0.710938
# Epoch  2, Batch  62 -Loss:  1206.5974 Validation Accuracy: 0.718750
# Epoch  2, Batch  63 -Loss:   781.8105 Validation Accuracy: 0.710938
# Epoch  2, Batch  64 -Loss:   967.8556 Validation Accuracy: 0.718750
# Epoch  2, Batch  65 -Loss:  1609.6873 Validation Accuracy: 0.718750
# Epoch  2, Batch  66 -Loss:  1121.0494 Validation Accuracy: 0.714844
# Epoch  2, Batch  67 -Loss:  1086.6426 Validation Accuracy: 0.722656
# Epoch  2, Batch  68 -Loss:  1061.4768 Validation Accuracy: 0.718750
# Epoch  2, Batch  69 -Loss:  1603.2080 Validation Accuracy: 0.718750
# Epoch  2, Batch  70 -Loss:  1162.8173 Validation Accuracy: 0.722656
# Epoch  2, Batch  71 -Loss:  1412.8462 Validation Accuracy: 0.718750
# Epoch  2, Batch  72 -Loss:  1123.4860 Validation Accuracy: 0.718750
# Epoch  2, Batch  73 -Loss:  1143.4280 Validation Accuracy: 0.714844
# Epoch  2, Batch  74 -Loss:  1413.4902 Validation Accuracy: 0.718750
# Epoch  2, Batch  75 -Loss:  1489.5737 Validation Accuracy: 0.718750
# Epoch  2, Batch  76 -Loss:  1338.7913 Validation Accuracy: 0.714844
# Epoch  2, Batch  77 -Loss:  1562.0400 Validation Accuracy: 0.718750
# Epoch  2, Batch  78 -Loss:   844.1052 Validation Accuracy: 0.718750
# Epoch  2, Batch  79 -Loss:  1227.6952 Validation Accuracy: 0.707031
# Epoch  2, Batch  80 -Loss:  1443.6506 Validation Accuracy: 0.707031
# Epoch  2, Batch  81 -Loss:  1030.2256 Validation Accuracy: 0.707031
# Epoch  2, Batch  82 -Loss:  1093.6536 Validation Accuracy: 0.710938
# Epoch  2, Batch  83 -Loss:  1427.7222 Validation Accuracy: 0.714844
# Epoch  2, Batch  84 -Loss:   743.3855 Validation Accuracy: 0.714844
# Epoch  2, Batch  85 -Loss:  1539.8909 Validation Accuracy: 0.714844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a0a709d70f6e> in <module>()
#      38                 x: mnist.validation.images[:test_valid_size],
#      39                 y: mnist.validation.labels[:test_valid_size],
# ---> 40                 keep_prob: 1.})
#      41
#      42             print('Epoch {:>2}, Batch {:>3} -'
#
# C:\Users\DELL\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\DELL\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# C:\Users\DELL\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\Users\DELL\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# C:\Users\DELL\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. Using Convolution Layers in TensorFlow

# %%
"""
Setup the strides, padding and filter weight/bias such that
the output shape is (1, 2, 2, 3).
"""
import tensorflow as tf
import numpy as np

# `tf.nn.conv2d` requires the input be 4D (batch_size, height, width, depth)
# (1, 4, 4, 1)
x = np.array([
    [0, 1, 0.5, 10],
    [2, 2.5, 1, -8],
    [4, 0, 5, 6],
    [15, 1, 2, 3]], dtype=np.float32).reshape((1, 4, 4, 1))
X = tf.constant(x)


def conv2d(input):
    # Filter (weights and bias)
    # The shape of the filter weight is (height, width, input_depth, output_depth)
    # The shape of the filter bias is (output_depth,)
    # TODO: Define the filter weights `F_W` and filter bias `F_b`.
    # NOTE: Remember to wrap them in `tf.Variable`, they are trainable parameters after all.
    F_W = tf.Variable(tf.truncated_normal((2,2,1,3)))
    # (height, width, input_depth, output_depth)
    F_b = tf.Variable(tf.zeros(3)) 
    # (output_depth)
    # TODO: Set the stride for each dimension (batch_size, height, width, depth)
    strides = [1, 2, 2, 1]
    # TODO: set the padding, either 'VALID' or 'SAME'.
    padding = 'VALID'
    # https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#conv2d
    # `tf.nn.conv2d` does not include the bias computation so we have to add it ourselves after.
    return tf.nn.conv2d(input, F_W, strides, padding) + F_b

out = conv2d(X)

# %% [markdown]
# # 4. Using Pooling Layers in TensorFlow

# %%
"""
Set the values to `strides` and `ksize` such that
the output shape after pooling is (1, 2, 2, 1).
"""
import tensorflow as tf
import numpy as np

# `tf.nn.max_pool` requires the input be 4D (batch_size, height, width, depth)
# (1, 4, 4, 1)
x = np.array([
    [0, 1, 0.5, 10],
    [2, 2.5, 1, -8],
    [4, 0, 5, 6],
    [15, 1, 2, 3]], dtype=np.float32).reshape((1, 4, 4, 1))
X = tf.constant(x)

def maxpool(input):
    # TODO: Set the ksize (filter size) for each dimension (batch_size, height, width, depth)
    ksize = [1, 2, 2, 1]
    # TODO: Set the stride for each dimension (batch_size, height, width, depth)
    strides = [1, 2, 2, 1]
    # TODO: set the padding, either 'VALID' or 'SAME'.
    padding = 'VALID'
    # https://www.tensorflow.org/versions/r0.11/api_docs/python/nn.html#max_pool
    return tf.nn.max_pool(input, ksize, strides, padding)
    
out = maxpool(X)
